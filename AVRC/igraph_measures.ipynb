# %%
import igraph as ig

# %%
G = ig.Graph.Read_Ncol("data/Cit-HepTh-igraph.txt", directed=True)

# %%
print(G.vcount())
# Out:
# 27770

# %%
print(G.vcount())
print(G.ecount())
# Out:
# 27770
# 352807

# %%
ecc = G.eccentricity()

# %%
ecc_dict = dict()

for v in G.vs:
    ecc_dict[v["name"]] = ecc[v.index]

print(ecc_dict)
# Out:
# {'1001': 24.0, '9304045': 1.0, '9308122': 1.0, '9309097': 1.0, '9311042': 1.0, '9401139': 4.0, '9404151': 4.0, '9407087': 5.0, '9408099': 6.0, '9501030': 6.0, '9503124': 7.0, '9504090': 5.0, '9504145': 2.0, '9505025': 8.0, '9505054': 8.0, '9505105': 8.0, '9505162': 8.0, '9506048': 9.0, '9506112': 9.0, '9506144': 9.0, '9507050': 9.0, '9507158': 8.0, '9508094': 11.0, '9508155': 12.0, '9510142': 13.0, '9510225': 12.0, '9510234': 13.0, '9511030': 12.0, '9511171': 13.0, '9601108': 11.0, '9602022': 9.0, '9602114': 9.0, '9603003': 16.0, '9603150': 17.0, '9603161': 16.0, '9603167': 10.0, '9605184': 17.0, '9605222': 10.0, '9606017': 16.0, '9606040': 18.0, '9607163': 17.0, '9607207': 17.0, '9608086': 14.0, '9609070': 12.0, '9609071': 12.0, '9609239': 13.0, '9611137': 14.0, '9612108': 13.0, '9701162': 12.0, '9702094': 27.0, '9702155': 13.0, '9702198': 13.0, '9703082': 11.0, '9703166': 13.0, '9704097': 13.0, '9705030': 12.0, '9705044': 12.0, '9705104': 12.0, '9705220': 29.0, '9706005': 13.0, '97
# ...
